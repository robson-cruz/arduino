# %% [markdown]
# # Circuito Divisor de Tensão Resistivo

# %% [markdown]
# $\displaystyle V_{out}=V_{in}*R_{2}/(R_{1}+R_{2})$

# %% [markdown]
# ![electrical_diagram_1.png](attachment:856c971d-f84e-4213-9544-ccc015daf28c.png)

# %% [markdown]
# ![voltage_divider_1.png](attachment:1265e2e1-f7ce-4004-b9a3-533438c32995.png)
